# %% [markdown]
# # Colab

# %%
# --- Setup your parameters ---
username = "matteopasqual02"  
repo = "Gradient-Gang/ANN-Challenges"
token = "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" 

# --- Clone command ---
# !pip install --no-deps git+https://{username}:{token}@github.com/{repo}.git
